# %% [markdown]
# # Thinking about Data / Statistics for Data Science
# ## Assignment (Part a)

# %% [markdown]
# This Jupyter Notebook contains your assignment questions and a corresponding place for your answers. **All your answers for this assignment are to appear in this and only this notebook!**
#
# Make sure that each cell of this notebook is appropriately set to either:
# 1. Markdown - for providing purely textual input
# 2. Code - for $R$ code; note comments can be included in this cell, but they are prefixed with a # symbol
#
# When answering a mathematical question, show how you got the answer so at least partial credit can be given if the provided answer was wrong. When providing textual input for an answer: adopt the philosophy that **"less can be more"**. Note that you may be asked to explain your answers -- so make sure your answers are yours.
#
# **Submission deadline:**  11:59pm on Sunday the 5th of September 2021 (**there will be no extension**)
#
# Late submissions will receive a 10\% reduction in marks for each day late.
#
# My advice is get started on this assignment immediately, that way you have time to seek assistance as needed.
#
# When the deadline for this assignment arrives, a copy of this (your Jupyter Notebook) will be taken from your home directory. So if you do the assignment off-line, make sure you upload into your home directory before the deadline! Make sure you do not rename this file!
#
# You may want to backup your assignment periodically, by downloading a copy.
#
# There are three questions and their worth is declared in the title. The question title also shows the break-down of marks according to the corresponding sub-questions. **Part a of the assignment is worth 20% of the final mark for this unit.**

# %%
# Adding comments to your code

# Any line that starts with a hash symbol is a comment
sample(0:7) # A comment can also end a line of code

# %% [markdown]
# ## Question 1: Probability (2 + 2 + 2 = 6 marks)

# %% [markdown]
# (i) A motorway has seven trucks for responding to calls for assistance. On average, 5.5 trucks are simultaneously involved in calls for assistance. What is the probability that more than six simultaneous calls for assistance may occur? Make sure you briefly include $R$ code comment(s) stating the logic of how you calculated the answer.

# %%
# Your R code to answer the question
ppois(6,5.5, lower.tail=TRUE)
# Out:
# [1] 0.686036

# %% [markdown]
# (ii) The probability of a childhood leukaemia patient having a relapse, within the first five years after successful treatment, is known to be 35%. For twelve patients who have recently completed treated, what is the probability (provide a single number) that either 7, 8, 9 or 10 will have a relapse? Make sure you briefly include $R$ code comment(s) stating the logic of how you calculated the answer.

# %%
# Your R code to answer the question

# %% [markdown]
# (iii) Using a normal distribution as a model for the height of Australian women and using the following population parameters sourced from the Australian Bureau of Statistics: population mean of 162.7cm and population variance of 50.4. What is the probability of seeing a woman whose height is between 160 and 170 cm? Make sure you briefly include $R$ code comment(s) stating the logic of how you calculated the answer.

# %%
# understanding th question.
# may be we can use pnorm over here to access the area under the curve from 160 - 170.
# like this? pnorm(170, mean=162.7, sd=sqrt(50.4)) - pnorm(160, mean=162.7, sd=sqrt(50.4))
# where are is given by
curve(dnorm(x, mean=162.7, sd=sqrt(50.4)), from=145, to=180)
abline(v=160, col="red")
abline(v=170, col="red")

# we have to find the area of the red lines under the curve.
# Out:
# plot without title

# %%
# Your R code to answer the question

# %% [markdown]
# ## Question 2: Probability & simulation (2 + 3 + 1 = 6 marks)
#
# Imagine an exam that consists of six multiple choice questions and each question has four possible answers, but only one is correct. Also imagine that answers to the questions are to be **randomly** selected. Make sure you briefly include $R$ code comment(s) stating the logic of how you calculated the answer.

# %% [markdown]
# (i) Determine the probability of getting at least five questions correct? Hence calculate the theoretical (exact) answer.

# %%
# Your R code to answer the question

# %% [markdown]
# (ii) Verify your answer by using simulation.

# %%
# Your R code to answer the question

# %% [markdown]
# (iii) By luck, what is the most answers you would expect to get right? In other words, which correct number of answers has the highest probability of occurring? Very briefly explain your answer.

# %%
# Your R code to answer the question

# %% [markdown]
# ## Question 3: Hypothesis testing (2 + 1 + 3 + 2 = 8 marks)
#
# The below table contains the fatalities due to traffic accidents and the distribution of population within Australia during 2018. The total number of fatalities during 2018 was 1,235.
#
# |            . | NSW | VIC | QLD | SA | WA | TAS | NT | ACT |
# |:------------:|:---:|:---:|:---:|:--:|:--:|:---:|:--:|:---:|
# | Fatalities % |  31 |  19 |  21 |  7 | 14 |   3 |  4 |   1 |
# | Population % |  32 |  26 |  20 |  7 | 10 |   2 |  1 |   2 |

# %% [markdown]
# (i) Load the above table content into an appropriate data structure. Produce a visualisation that shows how the distributions of fatalities and population vary.

# %%
# Your R code to answer the question

# %% [markdown]
# (ii) Using the above visualisation, make a prediction whether a difference exists in those distributions. Briefly explain your prediction and how you obtained it?

# %% [markdown]
# < Place your answer here >

# %% [markdown]
# (iii) Perform an appropriate hypothesis test in order to establish whether the distribution of Fatalities is different to Population? Include as comments in your $R$ code, the hypotheses used and any other details required in performing the test.

# %%
# Your R code to answer the question

# %% [markdown]
# (iv) Briefly provide the following:
# 1. The conclusion of your test and how you arrived at that conclusion
# 2. Briefly explain the implications of your conclusion

# %% [markdown]
# < Place your answer here >
